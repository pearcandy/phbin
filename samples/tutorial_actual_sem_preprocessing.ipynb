# %% [markdown]
# ## porespy + phbin
#
# ### preprocessing
#
# (c)pearcandy

# %%
import porespy as ps
import matplotlib.pyplot as plt
import numpy as np
import phbin, cv2
import scipy
from IPython.display import display, Image
# %matplotlib notebook

# %%
# !ls ./sem_original
# Out:
# entry18.jpg  entry20.jpg  entry22.jpg  entry3.jpg  fb3sdx.jpg  rd8.jpg
# entry19.jpg  entry21.jpg  entry23.jpg  fb1sdx.jpg  fb940.jpg

# %%
#sem0 = ps.generators.polydisperse_spheres([300,300],0.4,scipy.stats.norm(loc=10,scale=5))
#plt.imsave('./sem0',sem0,cmap='gray')
filename='entry18'
display(Image('./sem_original/'+filename+'.jpg'))

# %%
import cv2
# 画像読み込み
img = cv2.imread('./sem_original/'+filename+'.jpg')
print(img.shape)

# img[top : bottom, left : right]
# Out:
# (960, 1280, 3)

# %%
# サンプル1の切り出し、保存
img1 = img[0 : 840, 0: 1280]
cv2.imwrite("out_test.jpg", img1)
# Out:
# True

# %%
display(Image('./out_test.jpg'))

# %%
plt.close()
phbin.show_pixel_dist('./sem_original/'+filename+'.jpg')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
img, sem_bin = phbin.make_input_imgobj('./out_test.jpg',th=80)

# %%
plt.close()
plt.imshow(sem_bin,cmap='gray')
plt.imsave('./sem_binary/'+filename+'.jpg',sem_bin,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
